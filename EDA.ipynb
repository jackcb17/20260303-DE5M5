# %%
print("Hello World")
# Out:
# Hello World

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd()

data_dir = root/"data"
books = data_dir/"03_Library Systembook.csv"
customers = data_dir/"03_Library SystemCustomers.csv"

books_df = pd.read_csv(books)
cust_df = pd.read_csv(customers)

print("Books shape", books_df.shape)
print("Customer shape:", cust_df.shape)

books_df.head(2), cust_df.head(2)
# Out:
# Books shape (114, 6)
# Customer shape: (9, 2)
# (    Id                             Books Book checkout Book Returned  \
#  0  1.0               Catcher in the Rye   "20/02/2023"    25/02/2023
#  1  2.0  Lord of the rings the two towers  "24/03/2023"    21/03/2023
#
#    Days allowed to borrow  Customer ID
#  0                2 weeks          1.0
#  1                2 weeks          2.0  ,
#     Customer ID Customer Name
#  0          1.0      Jane Doe
#  1          2.0    John Smith)

# %%
books_df["Id"] = books_df["Id"].astype(int)
books_df["Book checkout"] = books_df["Books checkout"].str.replace(r'^["\']|["\']$','', regex =True)
books_df["Books"] = books_df["Books"].str.title()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 books_df["Id"] = books_df["Id"].astype(int)
#       2 books_df["Book checkout"] = books_df["Books checkout"].str.replace(r'^["\']|["\']$','', regex =True)
#       3 books_df["Books"] = books_df["Books"].str.title()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
books_df.head(5)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
books_df["Books"] = books_df["Books"].str.title()

# %%
books_df.head(5)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher In The Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord Of The Rings The Two Towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord Of The Rings The Return Of The Kind  "29/03/2023"    25/03/2023
# 3  4.0                                The Hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
type(books_df["Book Returned"])
# Out:
# pandas.core.series.Series

# %%
print(type(books_df["Book Returned"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
books_df["Days allowed to borrow"] = books_df["Days allowed to borrow"].str.replace(r"\bweeks\b","",regex = True)

# %%
books_df.head(5)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher In The Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord Of The Rings The Two Towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord Of The Rings The Return Of The Kind  "29/03/2023"    25/03/2023
# 3  4.0                                The Hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                     2           1.0
# 1                     2           2.0
# 2                     2           3.0
# 3                     2           4.0
# 4                     2           5.0

# %%
print(type(books_df["Days allowed to borrow"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(type(books_df["Days allowed to borrow"]))
#
# NameError: name 'books_df' is not defined

# %%
print(type[books_df["Days allowed to borrow"]])
# Out:
# type[0      2 weeks
# 1      2 weeks
# 2      2 weeks
# 3      2 weeks
# 4      2 weeks
#         ...
# 109        NaN
# 110        NaN
# 111        NaN
# 112        NaN
# 113        NaN
# Name: Days allowed to borrow, Length: 114, dtype: object]

# %%
books_df["Days allowed to borrow"].head(5)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Days allowed to borrow, dtype: object

# %%
import pandas as pd
books_df["Days allowed to borrow"] = books_df["Days allowed to borrow"].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 books_df["Days allowed to borrow"] = books_df["Days allowed to borrow"].astype(str).astype(int)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
# ...

# %%
books_df['Days allowed to borrow'].value_counts()
books_df['Days allowed to borrow'] = books_df['Days allowed to borrow']*7

# %%
books_df.head(5)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0         2 2 2 2 2 2 2           1.0
# 1         2 2 2 2 2 2 2           2.0
# 2         2 2 2 2 2 2 2           3.0
# 3         2 2 2 2 2 2 2           4.0
# 4         2 2 2 2 2 2 2           5.0

# %%
print(books_df['Days allowed to borrow'].dtype)
# Out:
# object

# %%
books_df['Days allowed to borrow'] = books_df['Days allowed to borrow'].str[0]

# %%
books_df.head(5)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                      2          1.0
# 1                      2          2.0
# 2                      2          3.0
# 3                      2          4.0
# 4                      2          5.0

# %%
books_df.tail(n=20)
# Out:
#      Id Books Book checkout Book Returned Days allowed to borrow  Customer ID
# 94  NaN   NaN           NaN           NaN                    NaN          NaN
# 95  NaN   NaN           NaN           NaN                    NaN          NaN
# 96  NaN   NaN           NaN           NaN                    NaN          NaN
# 97  NaN   NaN           NaN           NaN                    NaN          NaN
# 98  NaN   NaN           NaN           NaN                    NaN          NaN
# 99  NaN   NaN           NaN           NaN                    NaN          NaN
# 100 NaN   NaN           NaN           NaN                    NaN          NaN
# 101 NaN   NaN           NaN           NaN                    NaN          NaN
# 102 NaN   NaN           NaN           NaN                    NaN          NaN
# 103 NaN   NaN           NaN           NaN                    NaN          NaN
# 104 NaN   NaN           NaN           NaN                    NaN          NaN
# ...

# %%
books_df.head(50)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
books_df = books_df.dropna()

# %%
books_df = books_df[books_df['Days allowed to borrow'] != 'NaN']

# %%
books_df['Days allowed to borrow'] = books_df['Days allowed to borrow'].astype(int)
books_df.head(20)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
print(books_df['Days allowed to borrow'].dtype)
# Out:
# int32

# %%
books_df['Days allowed to borrow'] = books_df['Days allowed to borrow']*7

# %%
books_df.head(20)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...
